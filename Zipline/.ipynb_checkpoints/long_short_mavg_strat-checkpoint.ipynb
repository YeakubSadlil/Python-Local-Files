# %%
# %load_ext zipline
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %%
import pandas as pd
from zipline.api import order_target, record, symbol
import matplotlib.pyplot as plt

long_mavg_days = 40
short_mavg_days = 10

def initialize(context):
    context.i = 0
    context.asset = symbol('AAPL')


def handle_data(context, data):
    # Skip first long_mavg days to get full windows
    context.i += 1
    if context.i < long_mavg_days:
        return

    # Compute averages
    # data.history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = data.history(context.asset, 'price', 
                              bar_count=short_mavg_days, 
                              frequency="1d").mean()
    long_mavg = data.history(context.asset, 'price', 
                             bar_count=long_mavg_days, 
                             frequency="1d").mean()

    # Trading logic
    if short_mavg > long_mavg:
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target(context.asset, 100)
    elif short_mavg < long_mavg:
        order_target(context.asset, 0)

    # Save values for later inspection
    record(AAPL=data.current(context.asset, 'price'),
           short_mavg=short_mavg,
           long_mavg=long_mavg)

# %%
from zipline import run_algorithm
# import warnings
# warnings.filterwarnings('ignore')

start = pd.Timestamp('2014')
end = pd.Timestamp('2018')

perf = run_algorithm(start=start,
                       end=end,
                       initialize=initialize,
                       handle_data=handle_data,
                       capital_base=100_000,
                       bundle='quandl',
                       data_frequency='daily'
                    )

# %%
import matplotlib.pyplot as plt
from matplotlib import style

style.use('ggplot')

perf.columns
# Out:
# Index(['period_open', 'period_close', 'longs_count', 'shorts_count',
#        'long_value', 'short_value', 'long_exposure', 'pnl', 'capital_used',
#        'short_exposure', 'orders', 'transactions', 'positions',
#        'gross_leverage', 'starting_exposure', 'net_leverage',
#        'ending_exposure', 'starting_value', 'ending_value', 'returns',
#        'starting_cash', 'ending_cash', 'portfolio_value', 'algo_volatility',
#        'benchmark_period_return', 'benchmark_volatility', 'alpha', 'beta',
#        'sharpe', 'sortino', 'max_drawdown', 'algorithm_period_return',
#        'max_leverage', 'excess_return', 'treasury_period_return',
#        'trading_days', 'period_label', 'AAPL', 'short_mavg', 'long_mavg'],
#       dtype='object')

# %%
perf.tail()
# Out:
#                                         period_open              period_close  \
# 2017-12-22 21:00:00+00:00 2017-12-22 14:31:00+00:00 2017-12-22 21:00:00+00:00
# 2017-12-26 21:00:00+00:00 2017-12-26 14:31:00+00:00 2017-12-26 21:00:00+00:00
# 2017-12-27 21:00:00+00:00 2017-12-27 14:31:00+00:00 2017-12-27 21:00:00+00:00
# 2017-12-28 21:00:00+00:00 2017-12-28 14:31:00+00:00 2017-12-28 21:00:00+00:00
# 2017-12-29 21:00:00+00:00 2017-12-29 14:31:00+00:00 2017-12-29 21:00:00+00:00
#
#                            longs_count  shorts_count  long_value  short_value  \
# 2017-12-22 21:00:00+00:00            1             0     17501.0          0.0
# 2017-12-26 21:00:00+00:00            1             0     17057.0          0.0
# 2017-12-27 21:00:00+00:00            1             0     17060.0          0.0
# 2017-12-28 21:00:00+00:00            1             0     17108.0          0.0
# 2017-12-29 21:00:00+00:00            1             0     16923.0          0.0
#
#                            long_exposure    pnl  capital_used  short_exposure  \
# 2017-12-22 21:00:00+00:00        17501.0    0.0           0.0             0.0
# 2017-12-26 21:00:00+00:00        17057.0 -444.0           0.0             0.0
# 2017-12-27 21:00:00+00:00        17060.0    3.0           0.0             0.0
# 2017-12-28 21:00:00+00:00        17108.0   48.0           0.0             0.0
# 2017-12-29 21:00:00+00:00        16923.0 -185.0           0.0             0.0
#
#                            ... max_drawdown algorithm_period_return  \
# 2017-12-22 21:00:00+00:00  ...    -0.035059                0.107719
# 2017-12-26 21:00:00+00:00  ...    -0.035059                0.103279
# 2017-12-27 21:00:00+00:00  ...    -0.035059                0.103309
# 2017-12-28 21:00:00+00:00  ...    -0.035059                0.103789
# 2017-12-29 21:00:00+00:00  ...    -0.035059                0.101939
#
#                           max_leverage  excess_return  treasury_period_return  \
# 2017-12-22 21:00:00+00:00     0.621728            0.0                     0.0
# 2017-12-26 21:00:00+00:00     0.621728            0.0                     0.0
# 2017-12-27 21:00:00+00:00     0.621728            0.0                     0.0
# 2017-12-28 21:00:00+00:00     0.621728            0.0                     0.0
# 2017-12-29 21:00:00+00:00     0.621728            0.0                     0.0
#
#                            trading_days  period_label    AAPL  short_mavg  \
# 2017-12-22 21:00:00+00:00          1003       2017-12  175.01     173.806
# 2017-12-26 21:00:00+00:00          1004       2017-12  170.57     173.596
# 2017-12-27 21:00:00+00:00          1005       2017-12  170.60     173.486
# 2017-12-28 21:00:00+00:00          1006       2017-12  171.08     173.367
# 2017-12-29 21:00:00+00:00          1007       2017-12  169.23     173.068
#
#                            long_mavg
# 2017-12-22 21:00:00+00:00   171.8573
# 2017-12-26 21:00:00+00:00   172.0453
# 2017-12-27 21:00:00+00:00   172.1423
# 2017-12-28 21:00:00+00:00   172.1933
# 2017-12-29 21:00:00+00:00   172.2518
#
# [5 rows x 40 columns]

# %%
import matplotlib.pyplot as plt

# Figure 1
fig1, ax1 = plt.subplots()
perf.portfolio_value.plot(ax=ax1)
ax1.set_ylabel('portfolio value in $')

plt.show()

# Figure 2
fig2, ax2 = plt.subplots()
perf['AAPL'].plot(ax=ax2)
perf[['short_mavg', 'long_mavg']].plot(ax=ax2)

perf_trans = perf.loc[[t != [] for t in perf.transactions]]
buys = perf_trans.loc[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
sells = perf_trans.loc[[t[0]['amount'] < 0 for t in perf_trans.transactions]]
ax2.plot(buys.index, perf.short_mavg.loc[buys.index], '^', markersize=10, color='m')
ax2.plot(sells.index, perf.short_mavg.loc[sells.index], 'v', markersize=10, color='k')
ax2.set_ylabel('price in $')
plt.legend(loc=0)

plt.show()
