# %% [markdown]
# ## Efficient Frontier

# %%
import pandas as pd
ind = pd.read_csv("data/ind30_m_vw_rets.csv",header=0,index_col=0,parse_dates=True)/100

# %%
ind.head()
# Out:
#          Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 192607  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 192608  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 192609  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 192610 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 192611  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#          Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 192607  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 192608  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 192609  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 192610 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 192611  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#          Rtail   Meals   Fin     Other
# 192607  0.0007  0.0187  0.0037  0.0520
# ...

# %%
ind.index
# Out:
# Int64Index([192607, 192608, 192609, 192610, 192611, 192612, 192701, 192702,
#             192703, 192704,
#             ...
#             201803, 201804, 201805, 201806, 201807, 201808, 201809, 201810,
#             201811, 201812],
#            dtype='int64', length=1110)

# %%
ind.index = pd.to_datetime(ind.index,format="%Y%m").to_period("m")

# %%
ind.head()
# Out:
#           Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals   Fin     Other
# ...

# %%
ind.columns
# Out:
# Index(['Food ', 'Beer ', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth ',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal ', 'Oil  ', 'Util ', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin  ', 'Other'],
#       dtype='object')

# %%
ind.columns = ind.columns.str.strip()  # remove spaces after column names

# %%
ind.columns
# Out:
# Index(['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other'],
#       dtype='object')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import hedgefund as erk

# %%
erk.drawdownfunc(ind["Food"])["Drawdown"].plot(figsize=(14,8))
# Out:
# <Axes: >

# %%
erk.var_gaussian(ind).sort_values().plot.bar()
# Out:
# <Axes: >

# %%
ann_ret = erk.annualized_ret(ind["1996":"2000"],12).sort_values().plot.bar()

# %%
cov = ind["1996":"2000"].cov()

# %%
cov
# Out:
#            Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# Food   0.002609  0.002379  0.002061  0.000846  0.001035  0.001374  0.001733
# Beer   0.002379  0.005264  0.001359  0.001348  0.000865  0.002804  0.001704
# Smoke  0.002061  0.001359  0.008349  0.000379 -0.000128  0.001167  0.000950
# Games  0.000846  0.001348  0.000379  0.003773  0.001726  0.001206  0.002189
# Books  0.001035  0.000865 -0.000128  0.001726  0.002612  0.001025  0.002361
# Hshld  0.001374  0.002804  0.001167  0.001206  0.001025  0.003300  0.001320
# Clths  0.001733  0.001704  0.000950  0.002189  0.002361  0.001320  0.005655
# Hlth   0.001230  0.001955  0.001038  0.001433  0.000758  0.001473  0.000834
# Chems  0.001414  0.001460  0.000853  0.001775  0.001731  0.001413  0.002932
# Txtls  0.001216  0.002005  0.000779  0.001422  0.001459  0.001364  0.002472
# Cnstr  0.001487  0.002268  0.001446  0.002013  0.001753  0.002080  0.002937
# ...

# %%
erk.sharp_ratio(ind["1996":"2000"],0.03,12).sort_values().plot.bar(color="g")
# Out:
# <Axes: >

# %% [markdown]
# ## Efficient Frontier

# %%
def portfolio_return(weights,returns):
    """
    Weights -> Returns
    """
    return weight.T @ returns

def portfolio_vol(weights,returns):
    """
    Weights -> Volatility
    """
    return (weight.T @ covmat @ weights)**0.5

# %%
l = ["Food", 'Beer',"Smoke"]
ann_ret = erk.annualized_ret(ind["1996":"2000"],12)
ann_ret[l]
# Out:
# Food     0.116799
# Beer     0.141126
# Smoke    0.107830
# dtype: float64

# %%
cov.loc[l,l]
# Out:
#            Food      Beer     Smoke
# Food   0.002609  0.002379  0.002061
# Beer   0.002379  0.005264  0.001359
# Smoke  0.002061  0.001359  0.008349

# %%
import numpy as np
weights = np.repeat(1/4,3)

# %%
weights
# Out:
# array([0.25, 0.25, 0.25])

# %%
erk.portfolio_return(weights,ann_ret[l])
# Out:
# 0.0914387262874995

# %%
erk.portfolio_vol(weights,cov.loc[l,l])
# Out:
# 0.04169785388831471

# %% [markdown]
# ## 2 Asset Frontier

# %%
l = ["Games","Fin"]

# %%
n_points = 20

# %%
weights = [np.array([w,1-w]) for w in np.linspace(0,1,n_points)]
weights
# Out:
# [array([0., 1.]),
#  array([0.05263158, 0.94736842]),
#  array([0.10526316, 0.89473684]),
#  array([0.15789474, 0.84210526]),
#  array([0.21052632, 0.78947368]),
#  array([0.26315789, 0.73684211]),
#  array([0.31578947, 0.68421053]),
#  array([0.36842105, 0.63157895]),
#  array([0.42105263, 0.57894737]),
#  array([0.47368421, 0.52631579]),
#  array([0.52631579, 0.47368421]),
#  array([0.57894737, 0.42105263]),
#  array([0.63157895, 0.36842105]),
#  array([0.68421053, 0.31578947]),
#  array([0.73684211, 0.26315789]),
#  array([0.78947368, 0.21052632]),
#  array([0.84210526, 0.15789474]),
#  array([0.89473684, 0.10526316]),
#  array([0.94736842, 0.05263158]),
#  array([1., 0.])]

# %%
rets = [erk.portfolio_return(w,ann_ret[l]) for w in weights]
rets
# Out:
# [0.22337143343356036,
#  0.21520512368930153,
#  0.20703881394504264,
#  0.19887250420078378,
#  0.19070619445652492,
#  0.18253988471226607,
#  0.17437357496800718,
#  0.16620726522374832,
#  0.15804095547948946,
#  0.14987464573523063,
#  0.14170833599097174,
#  0.13354202624671288,
#  0.12537571650245402,
#  0.11720940675819516,
#  0.1090430970139363,
#  0.10087678726967743,
#  0.09271047752541857,
#  0.08454416778115972,
#  0.07637785803690085,
#  0.06821154829264198]

# %%
vol = [erk.portfolio_vol(w,cov.loc[l][l]) for w in weights]
vol
# Out:
# [0.0630997295785121,
#  0.06184548206317772,
#  0.06069878923524834,
#  0.05966585256137839,
#  0.058752672223312284,
#  0.05796490842860514,
#  0.05730773341483651,
#  0.05678568123574939,
#  0.056402504039475894,
#  0.0561610444586889,
#  0.05606313362372235,
#  0.05610952301512326,
#  0.056299855936855894,
#  0.05663268109748638,
#  0.05710550711027121,
#  0.05771489323047962,
#  0.05845656886221488,
#  0.05932557264732352,
#  0.06031640142594411,
#  0.061423159933946626]

# %%
ef = pd.DataFrame({"R":rets, "Vol":vol})

# %%
ef.head()
# Out:
#           R       Vol
# 0  0.223371  0.063100
# 1  0.215205  0.061845
# 2  0.207039  0.060699
# 3  0.198873  0.059666
# 4  0.190706  0.058753

# %%
ef.plot.scatter(x="Vol",y="R")
# Out:
# /home/yakub/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Vol', ylabel='R'>

# %% [markdown]
# ## N assest frontier

# %%
l = ["Games","Fin"]    # for two assests
erk.plot_ef2(20,ann_ret[l],cov.loc[l,l])
# Out:
# <Axes: xlabel='Volatility'>

# %%
def optimal_weights(n_points,er,cov):
    target_rs = np.linspace(er.min(),er.max(),n_points)
    weights = [minimize_vol(target_return,er,cov) for target_return in target_rs]
    return weights

def plot_ef(n_points,er,cov,style="-."):
    weights = optimal_weights(n_points,er,cov)
    rets = [erk.portfolio_return(w,er) for w in weights]
    vol  = [erk.portfolio_vol(w,cov) for w in weights]
    ef = pd.DataFrame(
    {
        "Returns": rets,
        "Volatility": vol
    })
    return ef.plot.line(x="Volatility",y="Returns", style=style)

# %%
from scipy.optimize import minimize

# %%
def minimize_vol(target_return,er,cov):
    """
    target_return -> weights
    """
    n = er.shape[0]
    init_guess = np.repeat(1/n,n)
    bounds = ((0.0,1.0),)*n
    return_is_target = {
        'type':'eq',
        'args': (er,),
        'fun' : lambda weights, er: target_return - erk.portfolio_return(weights,er)
    }
    weights_sum_to_1 ={
        'type':'eq',
        'fun' : lambda weights: np.sum(weights) -1 
    }
        
    results = minimize(erk.portfolio_vol,init_guess,
                      args=(cov,), method="SLSQP",
                      options={'disp':False},
                      constraints=(return_is_target,weights_sum_to_1),
                       bounds=bounds
                      )
    return results.x

# %%
l
# Out:
# ['Games', 'Fin']

# %%
w15 = minimize_vol(0.15,ann_ret[l],cov.loc[l,l])  # target_return is 15%

# %%
w15
# Out:
# array([0.47287631, 0.52712369])

# %%
vol15 = erk.portfolio_vol(w15,cov.loc[l,l])

# %%
vol15
# Out:
# 0.056163669406706564

# %%
erk.minimize_vol(0.15,ann_ret[l],cov.loc[l,l])
# Out:
# array([0.47287631, 0.52712369])

# %%
plot_ef(25,ann_ret[l],cov.loc[l,l])
# Out:
# <Axes: xlabel='Volatility'>
